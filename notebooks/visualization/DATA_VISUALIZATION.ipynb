# %% [markdown]
# LOADING THE DATASETS

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
cl_df=pd.read_csv('/content/cleaned_dataset.csv')
bal=pd.read_csv('/content/Balanced_dataset.csv')

# %% [markdown]
# BAR CHART(CLEANED DATASET)

# %%
x=cl_df['rating'].value_counts().index
y=cl_df['rating'].value_counts().values
sns.barplot(x=x, y=y)
plt.title("BAR PLOT-RATINGS COUNT")
plt.xlabel("Ratings")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# HORIZONTAL BAR PLOT(CLEANED DATASET)

# %%
plt.barh(x,y)
plt.title("HORIZONTAL BAR PLOT-RATINGS COUNT")
plt.xlabel("Count")
plt.ylabel("Ratings")
plt.show()

# %% [markdown]
# PIE CHART(CLEANED DATASET)

# %%
cl_df['rating'].value_counts().sort_index().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title("Ratings Proportion")
plt.ylabel('')
plt.show()

# %% [markdown]
# BAR CHART(BALANCED DATASET)

# %%
x=bal['rating'].value_counts().index
y=bal['rating'].value_counts().values
sns.barplot(x=x, y=y)
plt.title("BAR PLOT-RATINGS COUNT")
plt.xlabel("Ratings")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# HORIZONTAL BAR CHART(BALANCED DATASET)

# %%
plt.barh(x,y)
plt.title("HORIZONTAL BAR PLOT-RATINGS COUNT")
plt.xlabel("Count")
plt.ylabel("Ratings")
plt.show()

# %% [markdown]
# PIE CHART(BALANCED DATASET)

# %%
bal['rating'].value_counts().sort_index().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title("Ratings Proportion")
plt.ylabel('')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
imbal_df=pd.read_csv('/content/imbalance-dataset.csv')

# %% [markdown]
# BAR CHART(IMBALANCED DATASET)

# %%
x=imbal_df['rating'].value_counts().index
y=imbal_df['rating'].value_counts().values
sns.barplot(x=x, y=y)
plt.title("BAR PLOT-RATINGS COUNT")
plt.xlabel("Ratings")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# HORIZONTAL BAR CHART(IMBALANCED DATASET)

# %%
plt.barh(x,y)
plt.title("HORIZONTAL BAR PLOT-RATINGS COUNT")
plt.xlabel("Count")
plt.ylabel("Ratings")
plt.show()

# %% [markdown]
# PIE CHART(IMBALANCED DATASET)

# %%
imbal_df['rating'].value_counts().sort_index().plot.pie(autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'))
plt.title("Ratings Proportion")
plt.ylabel('')
plt.show()
